# %%
import math

# %%
pi = 3.141516

# %%
math.sin(pi)
# Out:
# 7.665358971797476e-05

# %%
result = []
s = 10
for i in range(s):
    result.append((math.sin(pi*i/s), math.cos(pi*i/s)))

# %%
result
# Out:
# [(0.0, 1.0),
#  (0.30900970417626195, 0.9510588849934052),
#  (0.5877728494120353, 0.8090260054497982),
#  (0.809003477406152, 0.587803856354102),
#  (0.9510470409433294, 0.3090461549881138),
#  (0.9999999992655284, 3.832679488713732e-05),
#  (0.9510707276464295, -0.3089732529104925),
#  (0.8090485323050313, -0.5877418416065635),
#  (0.5878348624327182, -0.8089809481741256),
#  (0.3090826053459946, -0.9510351954962194)]
